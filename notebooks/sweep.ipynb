# %%
import os
import numpy as np
import pandas as pd
import jax
import jax.numpy as jnp
import optax
import datasets
import models
import samplers
import matplotlib.pyplot as plt
from localization.experiments import make_key, simulate
from viz_box import entropy, position_mean_var, ipr, entropy_sort, mean_sort, var_sort, plot_receptive_fields

# %%
config = dict(
    seed=0,
    num_dimensions=40,
    num_hiddens=10,
    gain=10.,
    init_scale=1e-2,
    activation='shifted_relu',
    model_cls=models.MLP,
    optimizer_fn=optax.sgd,
    learning_rate=1e-3,
    batch_size=1,
    num_epochs=8000,
    dataset_cls=datasets.NonlinearGPDataset,
    xi1=3.0,#(0.45, 0.5),
    xi2=0.1,#(0.05, 0.1), 
    class_proportion=0.5,
    sampler_cls=samplers.EpochSampler,
    init_fn=models.xavier_normal_init
)
evaluation_interval = 500

# %%
config['gain'] = 0.1
path_key = make_key(**config)
weights = np.load(f"results/cluster/jax_results/fc1_{path_key}.npy")
metrics = pd.read_csv(f"results/cluster/jax_results/metrics_{path_key}.csv")
fig, axs = plot_receptive_fields(weights, num_cols=6, figsize=(20, 5), reordering_fn=entropy_sort, ind=-1, center_sort=True, evaluation_interval=evaluation_interval)

# %%
config['gain'] = 1.0
path_key = make_key(**config)
weights = np.load(f"results/cluster/jax_results/fc1_{path_key}.npy")
fig, axs = plot_receptive_fields(weights, num_cols=6, figsize=(20, 5), reordering_fn=entropy_sort, ind=-1, center_sort=True, evaluation_interval=evaluation_interval)

# %%
config['gain'] = 10.
path_key = make_key(**config)
weights = np.load(f"results/cluster/jax_results/fc1_{path_key}.npy")
fig, axs = plot_receptive_fields(weights, num_cols=6, figsize=(20, 5), reordering_fn=entropy_sort, ind=-1, center_sort=True, evaluation_interval=evaluation_interval)

# %%
config['gain'] = 0.1
config['num_hiddens'] = 10
config['save_'] = False

weights_, metrics_ = simulate(**config)
# Out:
# Using JAX backend: cpu
#
# Using configuration:
# {'activation': 'shifted_relu',
#  'batch_size': 1,
#  'class_proportion': 0.5,
#  'dataset_cls': <class 'datasets.nonlinear_gp.NonlinearGPDataset'>,
#  'gain': 0.1,
#  'init_fn': <function xavier_normal_init at 0x1556a98a0>,
#  'init_scale': 0.01,
#  'learning_rate': 0.001,
#  'model_cls': <class 'models.feedforward.MLP'>,
#  'num_dimensions': 40,
#  'num_epochs': 8000,
#  'num_hiddens': 10,
#  'optimizer_fn': <function sgd at 0x1555ef100>,
#  'sampler_cls': <class 'samplers.base.EpochSampler'>,
#  'save_': False,
#  'seed': 0,
#  'wandb_': False,
#  'xi1': 3.0,
#  'xi2': 0.1}
#
# Length of train dataset: 8000
# Length of eval dataset: 1000
# Length of train sampler: 8000
# Length of eval sampler: 1000
# Model:
# MLP(
#   fc1=Linear(
#     weight=f32[10,40],
#     bias=None,
#     in_features=40,
#     out_features=10,
#     use_bias=False
#   ),
#   act=<function <lambda>>,
#   fc2=Linear(
#     weight=f32[1,10],
#     bias=None,
#     in_features=10,
#     out_features=1,
#     use_bias=False
#   ),
#   tanh=<wrapped function <lambda>>
# )
#
# Starting evaluation...
# Completed evaluation over 1000 examples in 1.22 secs.
# ####
# ITERATION 0
# eval set:
# 	loss:		0.9980558753013611
# 	accuracy:	0.5329999923706055
# Evaluating every 500 training steps.
#
# Starting training...
# Length of train sampler: 8000
# Epoch 1 in 8.42 seconds.
# Starting evaluation...
# Completed evaluation over 1000 examples in 7.66 secs.
# ####
# ITERATION 500
# eval set:
# 	loss:		0.9985511302947998
# 	accuracy:	0.4909999966621399
# Epoch 2 in 7.04 seconds.
# Starting evaluation...
# Completed evaluation over 1000 examples in 8.71 secs.
# ####
# ITERATION 1000
# eval set:
# 	loss:		1.0120353698730469
# 	accuracy:	0.4690000116825104
# Epoch 3 in 8.14 seconds.
# Starting evaluation...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/leonlufkin/Documents/GitHub/Localization/sweep.ipynb Cell 6 line 5
#       <a href='vscode-notebook-cell:/Users/leonlufkin/Documents/GitHub/Localization/sweep.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> config['num_hiddens'] = 10
#       <a href='vscode-notebook-cell:/Users/leonlufkin/Documents/GitHub/Localization/sweep.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> config['save_'] = False
# ----> <a href='vscode-notebook-cell:/Users/leonlufkin/Documents/GitHub/Localization/sweep.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> weights_, metrics_ = simulate(**config)
#
# File ~/Documents/GitHub/Localization/experiments/batched_online.py:420, in simulate(num_hiddens, init_scale, activation, learning_rate, batch_size, num_epochs, xi1, xi2, num_dimensions, class_proportion, seed, dataset_cls, gain, model_cls, init_fn, optimizer_fn, sampler_cls, wandb_, save_)
#     417 epoch_time = time.time() - start_time
#     418 print(f"Epoch {train_step_num // evaluation_interval} in {epoch_time:0.2f} seconds.")
# --> 420 metrics_ = evaluate(
#     421   iteration=train_step_num,
#     422   dataset_split="eval",
#     423   sampler=eval_sampler,
#     424   model=eqx.tree_inference(model, True),
#     425   key=eval_key,
#     426   batch_size=len(eval_sampler),
#     427 )
#     429 log_to_wandb(metrics_) if wandb_ else metrics.append(metrics_)
#     431 weights.append(model.fc1.weight) #if gethostname() == 'Leons-MBP' else save_model_weights(train_step_num=train_step_num)
#
# File ~/Documents/GitHub/Localization/experiments/batched_online.py:187, in evaluate(iteration, dataset_split, key, model, sampler, batch_size)
#     184 print("Starting evaluation...")
#     185 start = time.time()
# --> 187 for i, (x, y) in enumerate(batcher(sampler, batch_size)):
#     188   # (key,) = jax.random.split(key, 1)
#     189   batch_metrics = _eval_step(x, y, jax.random.split(key, x.shape[0]))
#     190   for metric_name in incremental_metrics.keys():
#
# File ~/Documents/GitHub/Localization/experiments/batched_online.py:54, in batcher(sampler, batch_size)
#      52 # print("batcher: n=", n)
#      53 for i in range(0, n, batch_size):
# ---> 54   yield sampler[i : min(i + batch_size, n)]
#
# File ~/Documents/GitHub/Localization/samplers/base.py:223, in EpochSampler.__getitem__(self, index)
#     217 epoch_key = jax.random.fold_in(self.key, epoch_idx)
#     218 permuted_index = jax.random.permutation(
#     219   epoch_key,
#     220   jnp.arange(self.dataset_size),
#     221 )[index_in_epoch]
# --> 223 return self.dataset[permuted_index]
#
# File ~/Documents/GitHub/Localization/datasets/nonlinear_gp.py:98, in NonlinearGPDataset.__getitem__(self, index)
#      95 if isinstance(index, int):
#      96     keys = jnp.expand_dims(keys, axis=0)
# ---> 98 exemplars, labels = self.generate_xi(
#      99     key=keys,
#     100 )
#     102 if isinstance(index, int):
#     103   exemplars = exemplars[0]
#
# KeyboardInterrupt:
