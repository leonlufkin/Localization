# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import torch
from conv_emergence import main as simulate
from conv_emergence import compute_entropy as entropy
from conv_emergence import make_key
from viz_box import position_mean_var, ipr, entropy_sort, mean_sort, var_sort, plot_receptive_fields
from itertools import product

# %%
SWEEP = np.array(list(product(['tanh', 'relu'], ['mse', 'ce'], ['learnable_bias', 'linear', 0.0])))
def mini_sweep(task, xi1, xi2, L, K, batch_size, num_epochs, lr, second_scale=1.0, gain=None, save_=True):
    kwargs = dict(task=task, xi1=xi1, xi2=xi2, L=L, K=K, batch_size=batch_size, num_epochs=num_epochs, lr=lr, gain=gain, second_scale=second_scale, save_=save_)
    weights, losses, accs, iprs = [], [], [], []
    for activation, loss, second_layer in SWEEP:
        kwargs['activation'] = activation
        kwargs['loss'] = loss
        kwargs['second_layer'] = second_layer
        path_key = make_key(**kwargs)
        # print(path_key)
        if path_key + '.npz' in os.listdir('weights/'):
            print('Already simulated')
            data = np.load('weights/' + path_key + '.npz', allow_pickle=True)
            weights_, losses_, accs_, iprs_ = data['weights'], data['losses'], data['accs'], data['iprs']
        else:
            print('Simulating')
            weights_, (losses_, accs_, iprs_) = simulate(**kwargs)
        weights.append(weights_)
        losses.append(losses_); accs.append(accs_); iprs.append(iprs_)
    weights = np.array(weights)
    losses, accs, iprs = np.array(losses), np.array(accs), np.array(iprs)
    return weights, (losses, accs, iprs)

# %%
kwargs = dict(
    task='nlgp',
    xi1 = 4, #(0.55, 0.6), # (0.1, 0.6),
    xi2 = 2, #(0.05, 0.1),
    gain = 2,
    L = 40,
    K = 100,
    batch_size = 1000,
    num_epochs = 10000,
    save_ = False,
    lr = 0.05,#0.01,#0.1,
    activation = 'tanh',
    second_layer = 'linear',
    second_scale = 0.01 # 1.0 works well, 1e-4 works too but seem smaller in scale, down 1e-12 even works
)

# %%
kwargs = dict(
    task='single_pulse',
    xi1 = (0.5, 0.55), # (0.1, 0.6),
    xi2 = (0.15, 0.2),
    L = 100,
    K = 40,
    batch_size = 1000,
    num_epochs = 10000,
    save_ = True,
    lr = 0.1,#0.01,#0.1,
    # activation = 'relu', #'relu',
    # second_layer = -3.0, #'learnable_bias',
    second_scale = 1e-2, # 1.0 works well, 1e-4 works too but seem smaller in scale, down 1e-12 even works\
    # loss='ce',
)

# %%
weights, (losses, accs, iprs) = mini_sweep(**kwargs)
# Out:
# Already simulated
# Already simulated
# Simulating
# Arguments:
# task: single_pulse
# xi1: (0.5, 0.55)
# xi2: (0.15, 0.2)
# L: 100
# K: 40
# gain: None
# dim: 1
# batch_size: 1000
# num_epochs: 10000
# loss: mse
# lr: 0.1
# activation: tanh
# second_layer: 0.0
# second_scale: 0.01
# path: .
# save_: True
# kwargs: {}
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /Users/leonlufkin/Documents/GitHub/Localization/v_torch/studio.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/leonlufkin/Documents/GitHub/Localization/v_torch/studio.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> weights, (losses, accs, iprs) = mini_sweep(**kwargs)
#
# /Users/leonlufkin/Documents/GitHub/Localization/v_torch/studio.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/Users/leonlufkin/Documents/GitHub/Localization/v_torch/studio.ipynb#X34sZmlsZQ%3D%3D?line=14'>15</a> else:
#      <a href='vscode-notebook-cell:/Users/leonlufkin/Documents/GitHub/Localization/v_torch/studio.ipynb#X34sZmlsZQ%3D%3D?line=15'>16</a>     print('Simulating')
# ---> <a href='vscode-notebook-cell:/Users/leonlufkin/Documents/GitHub/Localization/v_torch/studio.ipynb#X34sZmlsZQ%3D%3D?line=16'>17</a>     weights_, (losses_, accs_, iprs_) = simulate(**kwargs)
#      <a href='vscode-notebook-cell:/Users/leonlufkin/Documents/GitHub/Localization/v_torch/studio.ipynb#X34sZmlsZQ%3D%3D?line=17'>18</a> weights.append(weights_)
#      <a href='vscode-notebook-cell:/Users/leonlufkin/Documents/GitHub/Localization/v_torch/studio.ipynb#X34sZmlsZQ%3D%3D?line=18'>19</a> losses.append(losses_); accs.append(accs_); iprs.append(iprs_)
#
# File ~/Documents/GitHub/Localization/v_torch/conv_emergence.py:321, in main(task, xi1, xi2, L, K, gain, dim, batch_size, num_epochs, loss, lr, activation, second_layer, second_scale, path, save_, **kwargs)
#     319         return F.relu(x) - self.shift
#     320 activation_fn = nn.Tanh() if activation == 'tanh' else nn.Sigmoid() if activation == 'sigmoid' else nn.ReLU() if activation == 'relu' else ShiftedRelu(shift=1.0) if activation == 'shifted_relu' else None
# --> 321 model = NeuralNet(input_dim=L ** dim, hidden_dim=K, activation=activation_fn, second_layer=second_layer, second_out_size=(1 if loss == 'mse' else 2), second_scale=second_scale)
#     322 opt = torch.optim.SGD(model.parameters(), lr=lr)
#     324 # save initial weights
#     325 # weight = model.ff1.weight.data.detach().cpu().numpy()
#     326 # bias = model.ff1.bias.data.detach().cpu().numpy()
#    (...)
#     329
#     330 # set up data
#
# File ~/Documents/GitHub/Localization/v_torch/conv_emergence.py:139, in NeuralNet.__init__(self, input_dim, hidden_dim, activation, second_layer, second_out_size, second_scale)
#     137     self.ff2 = Bias(learnable_bias, bias_value)
#     138 else:
# --> 139     raise NotImplementedError("second_layer must be 'linear', 'learnable_bias', or a float")
#     141 self.ff1 = self.ff1.to(device)
#     142 self.ff2 = self.ff2.to(device)
#
# NotImplementedError: second_layer must be 'linear', 'learnable_bias', or a float

# %%
fig, axs = plt.subplots(2, 4, figsize=(12, 4))
for i, ax in enumerate(axs.flatten()):
    ax.imshow(weights[i,-1,:,:])
    ax.set_title(" / ".join(SWEEP[i]), fontsize=10)

# %%
fig, axs = plt.subplots(2, 4, figsize=(12, 4))
for i, ax in enumerate(axs.flatten()):
    ax.plot(losses[i], label="loss")
    ax.plot(accs[i], label="acc")
    ax.set_title(" / ".join(SWEEP[i]), fontsize=10)
fig.tight_layout()

# %%
fig, axs = plt.subplots(2, 4, figsize=(12, 4))
for i, ax in enumerate(axs.flatten()):
    ax.plot(iprs[i], label="loss")
    ax.set_title(" / ".join(SWEEP[i]), fontsize=10)
fig.tight_layout()

# %%
weights, (losses, accs, iprs) = simulate(**kwargs)
# Out:
# Arguments:
# task: single_pulse
# xi1: (0.5, 0.55)
# xi2: (0.15, 0.2)
# L: 100
# K: 40
# gain: 1.1
# dim: 1
# batch_size: 1000
# num_epochs: 10000
# loss: ce
# lr: 1.0
# activation: relu
# second_layer: -3.0
# second_scale: 0.01
# path: .
# save_: False
# kwargs: {}
# Iteration 500: loss=0.3307, acc=0.9613, IPR>0.05=0.00%
# Iteration 1000: loss=0.2427, acc=1.0000, IPR>0.05=0.00%
# Iteration 1500: loss=0.2311, acc=1.0000, IPR>0.05=2.50%
# Iteration 2000: loss=0.2255, acc=1.0000, IPR>0.05=2.50%
# Iteration 2500: loss=0.2219, acc=1.0000, IPR>0.05=10.00%
# Iteration 3000: loss=0.2184, acc=1.0000, IPR>0.05=32.50%
# Iteration 3500: loss=0.2155, acc=1.0000, IPR>0.05=45.00%
# Iteration 4000: loss=0.2129, acc=1.0000, IPR>0.05=60.00%
# Iteration 4500: loss=0.2103, acc=1.0000, IPR>0.05=90.00%
# Iteration 5000: loss=0.2075, acc=1.0000, IPR>0.05=95.00%
# Iteration 5500: loss=0.2055, acc=1.0000, IPR>0.05=100.00%
# Iteration 6000: loss=0.2031, acc=1.0000, IPR>0.05=100.00%
# Iteration 6500: loss=0.2008, acc=1.0000, IPR>0.05=100.00%
# Iteration 7000: loss=0.1987, acc=1.0000, IPR>0.05=100.00%
# Iteration 7500: loss=0.1964, acc=1.0000, IPR>0.05=100.00%
# Iteration 8000: loss=0.1947, acc=1.0000, IPR>0.05=100.00%
# Iteration 8500: loss=0.1928, acc=1.0000, IPR>0.05=100.00%
# Iteration 9000: loss=0.1910, acc=1.0000, IPR>0.05=100.00%
# Iteration 9500: loss=0.1893, acc=1.0000, IPR>0.05=100.00%
# Iteration 10000: loss=0.1879, acc=1.0000, IPR>0.05=100.00%

# %%
# weights_ = np.swapaxes(weights, 1, 2)
fig, axs = plot_receptive_fields(weights, num_cols=21, evaluation_interval=500, figsize=(40, 20), reordering_fn=entropy_sort, ind=-1)

# %%
plot_receptive_fields(weights[-3:], num_cols=21, evaluation_interval=500, figsize=(40, 20), reordering_fn=entropy_sort, ind=-1)
# Out:
# (<Figure size 4000x2000 with 3 Axes>,
#  array([<Axes: xlabel='0', ylabel='Hidden neurons'>, <Axes: xlabel='500'>,
#         <Axes: xlabel='1000'>, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >, <Axes: >], dtype=object))

# %%
_ = plt.plot(np.stack([entropy(weight) for weight in weights]))

# %%
fig, axs = plt.subplots(2, 4, figsize=(15, 5))
for i, ax in enumerate(axs.flatten()):
    ax.plot(weights[-1,i,:])

# %%
fig, axs = plt.subplots(2, 4, figsize=(15, 5))
for i, ax in enumerate(axs.flatten()):
    ax.plot(weights[-1,i,:])

# %%
weight_ = weights[-1]
plt.imshow(weight_[:10], cmap='gray')
localized_inds = np.array([3, 4, 5, 6, 7, 9])
oscillatory_inds = np.array([0, 1, 2, 8])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4), sharey=True)
ax1.plot(weight_[localized_inds].T)
ax2.plot(weight_[oscillatory_inds].T)
# Out:
# [<matplotlib.lines.Line2D at 0x168a5e590>,
#  <matplotlib.lines.Line2D at 0x16876f250>,
#  <matplotlib.lines.Line2D at 0x16836da50>,
#  <matplotlib.lines.Line2D at 0x16836d890>]

# %% [markdown]
# ### With xi1 = [0.1,0.6)

# %%
fig, axs = plot_receptive_fields(weights, num_cols=21, evaluation_interval=500, figsize=(20, 8), reordering_fn=entropy_sort, ind=-1)

# %%
weight_ = weights[-1]
plt.imshow(weight_[:10], cmap='gray')
localized_inds = np.array([0, 4, 5, 9])
oscillatory_inds = np.array([1, 2, 3, 6, 7, 8])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4), sharey=True)
ax1.plot(weight_[localized_inds].T)
ax2.plot(weight_[oscillatory_inds].T)
# Out:
# [<matplotlib.lines.Line2D at 0x16a800fd0>,
#  <matplotlib.lines.Line2D at 0x16a801550>,
#  <matplotlib.lines.Line2D at 0x16a801a90>,
#  <matplotlib.lines.Line2D at 0x16a801ed0>,
#  <matplotlib.lines.Line2D at 0x16a8022d0>,
#  <matplotlib.lines.Line2D at 0x16a802850>]

# %%
plt.plot(iprs)
# Out:
# [<matplotlib.lines.Line2D at 0x16a920550>,
#  <matplotlib.lines.Line2D at 0x16a92d310>,
#  <matplotlib.lines.Line2D at 0x16a92d690>,
#  <matplotlib.lines.Line2D at 0x16a92d910>,
#  <matplotlib.lines.Line2D at 0x16a92dd90>,
#  <matplotlib.lines.Line2D at 0x16a92e150>,
#  <matplotlib.lines.Line2D at 0x16a92e590>,
#  <matplotlib.lines.Line2D at 0x16a92e990>,
#  <matplotlib.lines.Line2D at 0x16a92dd10>,
#  <matplotlib.lines.Line2D at 0x16a8a6250>,
#  <matplotlib.lines.Line2D at 0x16a92f490>,
#  <matplotlib.lines.Line2D at 0x16a91f910>,
#  <matplotlib.lines.Line2D at 0x16a8d7cd0>,
#  <matplotlib.lines.Line2D at 0x16a92ffd0>,
#  <matplotlib.lines.Line2D at 0x16a940350>,
#  <matplotlib.lines.Line2D at 0x16a940850>,
#  <matplotlib.lines.Line2D at 0x16a940bd0>,
#  <matplotlib.lines.Line2D at 0x16a923a90>,
#  <matplotlib.lines.Line2D at 0x16a941210>,
#  <matplotlib.lines.Line2D at 0x16a9415d0>,
#  <matplotlib.lines.Line2D at 0x16a8c9a90>,
#  <matplotlib.lines.Line2D at 0x16a941ed0>,
#  <matplotlib.lines.Line2D at 0x16a9420d0>,
#  <matplotlib.lines.Line2D at 0x16a942490>,
#  <matplotlib.lines.Line2D at 0x16a942890>,
#  <matplotlib.lines.Line2D at 0x16a942c10>,
#  <matplotlib.lines.Line2D at 0x16a943190>,
#  <matplotlib.lines.Line2D at 0x16a9434d0>,
#  <matplotlib.lines.Line2D at 0x16a943790>,
#  <matplotlib.lines.Line2D at 0x16a943890>,
#  <matplotlib.lines.Line2D at 0x16a943f90>,
#  <matplotlib.lines.Line2D at 0x16a9143d0>,
#  <matplotlib.lines.Line2D at 0x16a94c690>,
#  <matplotlib.lines.Line2D at 0x16a94ca90>,
#  <matplotlib.lines.Line2D at 0x16a91cf10>,
#  <matplotlib.lines.Line2D at 0x16a94d290>,
#  <matplotlib.lines.Line2D at 0x16a94d550>,
#  <matplotlib.lines.Line2D at 0x16a94d950>,
#  <matplotlib.lines.Line2D at 0x16a6e5e50>,
#  <matplotlib.lines.Line2D at 0x16a8a6210>,
#  <matplotlib.lines.Line2D at 0x16a89e590>,
#  <matplotlib.lines.Line2D at 0x16a94e810>,
#  <matplotlib.lines.Line2D at 0x16a776d10>,
#  <matplotlib.lines.Line2D at 0x16a5f70d0>,
#  <matplotlib.lines.Line2D at 0x16a91f450>,
#  <matplotlib.lines.Line2D at 0x16a8d77d0>,
#  <matplotlib.lines.Line2D at 0x16a917b50>,
#  <matplotlib.lines.Line2D at 0x16a94fdd0>,
#  <matplotlib.lines.Line2D at 0x16a950210>,
#  <matplotlib.lines.Line2D at 0x16a820750>,
#  <matplotlib.lines.Line2D at 0x16a950a50>,
#  <matplotlib.lines.Line2D at 0x16a950ed0>,
#  <matplotlib.lines.Line2D at 0x16a951310>,
#  <matplotlib.lines.Line2D at 0x16a819850>,
#  <matplotlib.lines.Line2D at 0x16a951b90>,
#  <matplotlib.lines.Line2D at 0x16a951f90>,
#  <matplotlib.lines.Line2D at 0x16a952590>,
#  <matplotlib.lines.Line2D at 0x16a87a950>,
#  <matplotlib.lines.Line2D at 0x16a81ad90>,
#  <matplotlib.lines.Line2D at 0x16a9530d0>,
#  <matplotlib.lines.Line2D at 0x16a92f590>,
#  <matplotlib.lines.Line2D at 0x16a9537d0>,
#  <matplotlib.lines.Line2D at 0x16a943c50>,
#  <matplotlib.lines.Line2D at 0x16a958110>,
#  <matplotlib.lines.Line2D at 0x16a9204d0>,
#  <matplotlib.lines.Line2D at 0x16a958810>,
#  <matplotlib.lines.Line2D at 0x16a958c50>,
#  <matplotlib.lines.Line2D at 0x16a9590d0>,
#  <matplotlib.lines.Line2D at 0x16a959550>,
#  <matplotlib.lines.Line2D at 0x16a889a50>,
#  <matplotlib.lines.Line2D at 0x16a959f10>,
#  <matplotlib.lines.Line2D at 0x16a95a190>,
#  <matplotlib.lines.Line2D at 0x16a81a6d0>,
#  <matplotlib.lines.Line2D at 0x16a95a9d0>,
#  <matplotlib.lines.Line2D at 0x16a95ae50>,
#  <matplotlib.lines.Line2D at 0x16a95b290>,
#  <matplotlib.lines.Line2D at 0x16a95b610>,
#  <matplotlib.lines.Line2D at 0x16a95bc90>,
#  <matplotlib.lines.Line2D at 0x16a95bf90>,
#  <matplotlib.lines.Line2D at 0x16a8ef8d0>,
#  <matplotlib.lines.Line2D at 0x16a964790>,
#  <matplotlib.lines.Line2D at 0x16a964bd0>,
#  <matplotlib.lines.Line2D at 0x16a8b5150>,
#  <matplotlib.lines.Line2D at 0x16a965490>,
#  <matplotlib.lines.Line2D at 0x16a45d9d0>,
#  <matplotlib.lines.Line2D at 0x16a60ddd0>,
#  <matplotlib.lines.Line2D at 0x16a8a61d0>,
#  <matplotlib.lines.Line2D at 0x16a9664d0>,
#  <matplotlib.lines.Line2D at 0x16a966910>,
#  <matplotlib.lines.Line2D at 0x16a92ee50>,
#  <matplotlib.lines.Line2D at 0x16a967150>,
#  <matplotlib.lines.Line2D at 0x16a8d76d0>,
#  <matplotlib.lines.Line2D at 0x16a8e7a90>,
#  <matplotlib.lines.Line2D at 0x16a877e90>,
#  <matplotlib.lines.Line2D at 0x16a9682d0>,
#  <matplotlib.lines.Line2D at 0x16a9685d0>,
#  <matplotlib.lines.Line2D at 0x16a950b50>,
#  <matplotlib.lines.Line2D at 0x16a968e10>,
#  <matplotlib.lines.Line2D at 0x16a829350>,
#  <matplotlib.lines.Line2D at 0x16a969650>]
